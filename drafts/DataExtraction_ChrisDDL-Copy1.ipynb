# %%
### Checking data for Chris

import os
import scanpy as sc
import pandas as pd
import dandelion as ddl
from tqdm import tqdm

# %%
os.getcwd()
# Out:
# 'G:\\My Drive\\QBIO7008\\R Drive'

# %%
adult = sc.read_h5ad()

# %%
adata = sc.read_h5ad("data/Fetal/FICA_Bcell_BCR_Suo2022.h5ad")

# %%
adata.obs
# Out:
#                                          n_counts  n_genes  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC   12236.0     2627
# Human_colon_16S8159187-TTAGGCATCAAGAAGT   11355.0     2709
# Human_colon_16S8159187-AGAATAGAGTGTGAAT    8394.0     2161
# Human_colon_16S8159187-GGATTACAGAGAGCTC    7740.0     2316
# Human_colon_16S8159187-TTCTACACATACAGCT    6661.0     1625
# ...                                           ...      ...
# FCAImmP7803020-CGATCGGGTAGAGCTG            2074.0      693
# FCAImmP7803020-AGACGTTAGAGGTTAT            2064.0      890
# FCAImmP7803020-GTGTTAGCACCGGAAA            2048.0      737
# FCAImmP7803020-ACACCGGGTGTCTGAT            2040.0      734
# FCAImmP7803020-CGATGTAGTCTGCGGT            2018.0      826
#
#                                                            file      mito  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC  Human_colon_16S8159187  0.032772
# Human_colon_16S8159187-TTAGGCATCAAGAAGT  Human_colon_16S8159187  0.035315
# Human_colon_16S8159187-AGAATAGAGTGTGAAT  Human_colon_16S8159187  0.024184
# Human_colon_16S8159187-GGATTACAGAGAGCTC  Human_colon_16S8159187  0.024419
# Human_colon_16S8159187-TTCTACACATACAGCT  Human_colon_16S8159187  0.014112
# ...                                                         ...       ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                  FCAImmP7803020  0.030858
# FCAImmP7803020-AGACGTTAGAGGTTAT                  FCAImmP7803020  0.021318
# FCAImmP7803020-GTGTTAGCACCGGAAA                  FCAImmP7803020  0.016113
# FCAImmP7803020-ACACCGGGTGTCTGAT                  FCAImmP7803020  0.059804
# FCAImmP7803020-CGATGTAGTCTGCGGT                  FCAImmP7803020  0.038652
#
#                                          doublet_scores predicted_doublets  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC        0.293388               True
# Human_colon_16S8159187-TTAGGCATCAAGAAGT        0.136000              False
# Human_colon_16S8159187-AGAATAGAGTGTGAAT        0.195231              False
# Human_colon_16S8159187-GGATTACAGAGAGCTC        0.112676              False
# Human_colon_16S8159187-TTCTACACATACAGCT        0.109792              False
# ...                                                 ...                ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                0.030568              False
# FCAImmP7803020-AGACGTTAGAGGTTAT                0.023443              False
# FCAImmP7803020-GTGTTAGCACCGGAAA                0.028409              False
# FCAImmP7803020-ACACCGGGTGTCTGAT                0.031688              False
# FCAImmP7803020-CGATGTAGTCTGCGGT                0.008183              False
#
#                                         old_annotation_uniform organ  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC                    nan    GU
# Human_colon_16S8159187-TTAGGCATCAAGAAGT                    nan    GU
# Human_colon_16S8159187-AGAATAGAGTGTGAAT                    nan    GU
# Human_colon_16S8159187-GGATTACAGAGAGCTC                    nan    GU
# Human_colon_16S8159187-TTCTACACATACAGCT                    nan    GU
# ...                                                        ...   ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                            nan    SP
# FCAImmP7803020-AGACGTTAGAGGTTAT                         B CELL    SP
# FCAImmP7803020-GTGTTAGCACCGGAAA                            nan    SP
# FCAImmP7803020-ACACCGGGTGTCTGAT                            nan    SP
# FCAImmP7803020-CGATGTAGTCTGCGGT                         B CELL    SP
#
#                                              Sort_id  age  ... mu_freq  \
# index                                                      ...
# Human_colon_16S8159187-AGCTCTCAGTGTACTC  CD45P_CD45N   15  ...     0.0
# Human_colon_16S8159187-TTAGGCATCAAGAAGT  CD45P_CD45N   15  ...     0.0
# Human_colon_16S8159187-AGAATAGAGTGTGAAT  CD45P_CD45N   15  ...     0.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC  CD45P_CD45N   15  ...     NaN
# Human_colon_16S8159187-TTCTACACATACAGCT  CD45P_CD45N   15  ...     NaN
# ...                                              ...  ...  ...     ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                CD45P   15  ...     NaN
# FCAImmP7803020-AGACGTTAGAGGTTAT                CD45P   15  ...     0.0
# FCAImmP7803020-GTGTTAGCACCGGAAA                CD45P   15  ...     NaN
# FCAImmP7803020-ACACCGGGTGTCTGAT                CD45P   15  ...     NaN
# FCAImmP7803020-CGATGTAGTCTGCGGT                CD45P   15  ...     0.0
#
#                                         junction_length_VDJ  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC                45.0
# Human_colon_16S8159187-TTAGGCATCAAGAAGT                21.0
# Human_colon_16S8159187-AGAATAGAGTGTGAAT                51.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC                 NaN
# Human_colon_16S8159187-TTCTACACATACAGCT                 NaN
# ...                                                     ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                         NaN
# FCAImmP7803020-AGACGTTAGAGGTTAT                        57.0
# FCAImmP7803020-GTGTTAGCACCGGAAA                         NaN
# FCAImmP7803020-ACACCGGGTGTCTGAT                         NaN
# FCAImmP7803020-CGATGTAGTCTGCGGT                        48.0
#
#                                         junction_length_VJ  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC               33.0
# Human_colon_16S8159187-TTAGGCATCAAGAAGT               39.0
# Human_colon_16S8159187-AGAATAGAGTGTGAAT               36.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC                NaN
# Human_colon_16S8159187-TTCTACACATACAGCT                NaN
# ...                                                    ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                        NaN
# FCAImmP7803020-AGACGTTAGAGGTTAT                       42.0
# FCAImmP7803020-GTGTTAGCACCGGAAA                        NaN
# FCAImmP7803020-ACACCGGGTGTCTGAT                        NaN
# FCAImmP7803020-CGATGTAGTCTGCGGT                       33.0
#
#                                         junction_aa_length_VDJ  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC                   15.0
# Human_colon_16S8159187-TTAGGCATCAAGAAGT                    7.0
# Human_colon_16S8159187-AGAATAGAGTGTGAAT                   17.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC                    NaN
# Human_colon_16S8159187-TTCTACACATACAGCT                    NaN
# ...                                                        ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                            NaN
# FCAImmP7803020-AGACGTTAGAGGTTAT                           19.0
# FCAImmP7803020-GTGTTAGCACCGGAAA                            NaN
# FCAImmP7803020-ACACCGGGTGTCTGAT                            NaN
# FCAImmP7803020-CGATGTAGTCTGCGGT                           16.0
#
#                                         junction_aa_length_VJ  np1_length_VDJ  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC                  11.0            16.0
# Human_colon_16S8159187-TTAGGCATCAAGAAGT                  13.0             3.0
# Human_colon_16S8159187-AGAATAGAGTGTGAAT                  12.0             6.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC                   NaN             NaN
# Human_colon_16S8159187-TTCTACACATACAGCT                   NaN             NaN
# ...                                                       ...             ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                           NaN             NaN
# FCAImmP7803020-AGACGTTAGAGGTTAT                          14.0            31.0
# FCAImmP7803020-GTGTTAGCACCGGAAA                           NaN             NaN
# FCAImmP7803020-ACACCGGGTGTCTGAT                           NaN             NaN
# FCAImmP7803020-CGATGTAGTCTGCGGT                          11.0             7.0
#
#                                         np1_length_VJ np2_length_VDJ  \
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC           0.0            NaN
# Human_colon_16S8159187-TTAGGCATCAAGAAGT           1.0            NaN
# Human_colon_16S8159187-AGAATAGAGTGTGAAT           0.0            8.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC           NaN            NaN
# Human_colon_16S8159187-TTCTACACATACAGCT           NaN            NaN
# ...                                               ...            ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                   NaN            NaN
# FCAImmP7803020-AGACGTTAGAGGTTAT                   9.0            NaN
# FCAImmP7803020-GTGTTAGCACCGGAAA                   NaN            NaN
# FCAImmP7803020-ACACCGGGTGTCTGAT                   NaN            NaN
# FCAImmP7803020-CGATGTAGTCTGCGGT                   0.0            2.0
#
#                                          clone_id_size clone_id_size_max_3
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC            1.0                 1.0
# Human_colon_16S8159187-TTAGGCATCAAGAAGT            1.0                 1.0
# Human_colon_16S8159187-AGAATAGAGTGTGAAT            1.0                 1.0
# Human_colon_16S8159187-GGATTACAGAGAGCTC            NaN                 nan
# Human_colon_16S8159187-TTCTACACATACAGCT            NaN                 nan
# ...                                                ...                 ...
# FCAImmP7803020-CGATCGGGTAGAGCTG                    NaN                 nan
# FCAImmP7803020-AGACGTTAGAGGTTAT                    1.0                   1
# FCAImmP7803020-GTGTTAGCACCGGAAA                    NaN                 nan
# FCAImmP7803020-ACACCGGGTGTCTGAT                    NaN                 nan
# FCAImmP7803020-CGATGTAGTCTGCGGT                    1.0                   1
#
# [29818 rows x 71 columns]

# %%
adata.obs["celltype_annotation"]
# Out:
# index
# Human_colon_16S8159187-AGCTCTCAGTGTACTC      MATURE_B
# Human_colon_16S8159187-TTAGGCATCAAGAAGT            B1
# Human_colon_16S8159187-AGAATAGAGTGTGAAT      MATURE_B
# Human_colon_16S8159187-GGATTACAGAGAGCTC         PRO_B
# Human_colon_16S8159187-TTCTACACATACAGCT            B1
#                                               ...
# FCAImmP7803020-CGATCGGGTAGAGCTG              MATURE_B
# FCAImmP7803020-AGACGTTAGAGGTTAT            IMMATURE_B
# FCAImmP7803020-GTGTTAGCACCGGAAA            IMMATURE_B
# FCAImmP7803020-ACACCGGGTGTCTGAT              MATURE_B
# FCAImmP7803020-CGATGTAGTCTGCGGT              MATURE_B
# Name: celltype_annotation, Length: 29818, dtype: category
# Categories (10, object): ['B1', 'CYCLING_B', 'IMMATURE_B', 'LARGE_PRE_B', ..., 'PLASMA_B', 'PRE_PRO_B', 'PRO_B', 'SMALL_PRE_B']

# %%
## getting a list of all b cell types and the number of cells... 

adata.obs["celltype_annotation"].value_counts()
# Out:
# MATURE_B       8901
# LARGE_PRE_B    4702
# SMALL_PRE_B    4642
# B1             2897
# LATE_PRO_B     2887
# PRO_B          2771
# IMMATURE_B     1106
# PRE_PRO_B       967
# CYCLING_B       920
# PLASMA_B         25
# Name: celltype_annotation, dtype: int64

# %%
## making a subset of every B cell type..

adata_Bcell = adata[adata.obs['celltype_annotation'].isin
                    (['MATURE_B', 'LARGE_PRE_B', 'SMALL_PRE_B', 'PRO_B', 'LATE_PRO_B',
                     'B1', 'PRE_PRO_B', 'IMMATURE_B', 'CYCLING_B', 'PLASMA_B'])]

# %%
adata_Bcell.obs["celltype_annotation"].value_counts()
# Out:
# MATURE_B       8901
# LARGE_PRE_B    4702
# SMALL_PRE_B    4642
# B1             2897
# LATE_PRO_B     2887
# PRO_B          2771
# IMMATURE_B     1106
# PRE_PRO_B       967
# CYCLING_B       920
# PLASMA_B         25
# Name: celltype_annotation, dtype: int64

# %%
# save data
adata_Bcell.write_h5ad("data/Fetal/FICA_Bcell_GEX_Suo2022.h5ad", compression="gzip")

# %%
### let's check out the adult one too... 

bdata = sc.read_h5ad('data/Adult/TICA_B_BCR.h5ad')

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 29944 × 1196
#     obs: 'sample', 'Source ID', 'sex', 'patient no', 'organ code', 'sample ID', 'fraction_mito', 'n_genes', 'n_counts', 'log_counts', 'batch', 'organ_code', 'donor_id', 'combined_ID', 'HTO_C0251', 'HTO_C0252', 'HTO_C0253', 'HTO_C0254', 'HTO_C0255', 'HTO_C0256', 'HTO_C0257', 'total_hto_counts', 'fraction_HTO_C0251', 'fraction_HTO_C0252', 'most_likely_hypothesis', 'cluster_feature', 'negative_hypothesis_probability', 'singlet_hypothesis_probability', 'doublet_hypothesis_probability', 'Classification', 'fraction_HTO_C0253', 'fraction_HTO_C0254', 'fraction_HTO_C0255', 'fraction_HTO_C0256', 'fraction_HTO_C0257', 'hash+lib', 'sample_ID', 'leiden', 'Stimulation', 'C251', 'C252', 'C253', 'C254', 'C255', 'C256', 'C257', 'C258', 'fraction_HTOC251', 'fraction_HTOC252', 'fraction_HTOC253', 'fraction_HTOC254', 'fraction_HTOC255', 'fraction_HTOC256', 'fraction_HTOC257', 'fraction_HTOC258', 'chem', 'index', 'scrublet_leiden', 'scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'is_doublet', 'predicted_labels', 'new_predicted_labels_high', 'new_predicted_labels', 'new_pred_leiden', 'endo_leiden', 'compartment', 'Category', 'anno_B_v2', 'leiden_20', 'new_predicted_labels_maj', 'new_predicted_labels_maj20', 'anno_B_v2_maj', 'manual_annot', 'leiden_sub0', 'leiden_sub0_sub7', 'naive_prog_leiden', 'subdivide_0_7_16', 'manual_annot_v2', 'score_Early_plasma', 'score_BMA_plasma', 'score_plasmablast', 'BCR_barcode', 'GEX_barcode', 'BCR_ID', 'IGH', 'IGK', 'IGL', 'ChainCombination', 'ChainStatus', 'sequence_id', 'IgH_productive', 'IgH_vj_in_frame', 'IgH_stop_codon', 'IgH_v_call_genotyped', 'IgH_d_call', 'IgH_j_call', 'IgH_junction_length', 'isotype', 'clone_id', 'pandonor_clone_id', 'donor.x', 'IgK_c_gene', 'IgK_vdj', 'IgK_full_length', 'IgK_productive', 'IgL_c_gene', 'IgL_vdj', 'IgL_full_length', 'IgL_productive', 'MultiISOTYPE', 'MultiIGH_V_CALL_GENOTYPED', 'MultiIGH_J_CALL', 'MultiIGH_PRODUCTIVE', 'MultiIGH_JUNCTION_LENGTH', 'MultiCLONE_ID', 'IgH_length', 'IgH_reads', 'IgH_umis', 'dist_nearest', 'pandonor_dist_nearest', 'IgH_mu_freq', 'IgK_reads', 'IgK_umis', 'IgL_reads', 'IgL_umis', 'CLONE', 'barcode', 'cell_barcode_prefix', 'donor.y', 'Identity', 'SAMPLE', 'DONOR', 'TISSUE', 'replicate'
#     var: 'gene_ids', 'feature_types', 'highly_variable-1-0', 'means-1-0', 'dispersions-1-0', 'dispersions_norm-1-0', 'mean-1-0', 'std-1-0', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Category_colors', 'IgH_productive_colors', 'anno_B_v2_colors', 'compartment_colors', 'donor_id_colors', 'endo_leiden_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_sub0_colors', 'leiden_sub0_sub7_colors', 'manual_annot_colors', 'manual_annot_v2_colors', 'naive_prog_leiden_colors', 'neighbors', 'new_predicted_labels_colors', 'new_predicted_labels_high_colors', 'pca', 'plasma_DE', 'predicted_labels_colors', 'rank_genes_groups', 'subdivide_0_7_16_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'X_explained'
#     obsp: 'connectivities', 'distances'

# %%
bdata.obs['manual_annot_v2'].value_counts()
# Out:
# Memory B cells                   15938
# Naive B cells                     9417
# Plasma cells                      2055
# Age-associated memory B cells      720
# T/B doublets                       642
# MNP/B doublets                     450
# Plasmablasts                       406
# GC_B (I)                           169
# GC_B (II)                          101
# Pre-B                               44
# Pro-B                                2
# Name: manual_annot_v2, dtype: int64

# %%
# read in the data
cdata = sc.read_h5ad('data/Fetal/raw_fulllymphoiddata/PAN.A01.v01.raw_count.20210429.LYMPHOID.embedding.BCR.h5ad')

# %%
cdata.obs_keys
# Out:
# <bound method AnnData.obs_keys of AnnData object with n_obs × n_vars = 77976 × 33538
#     obs: 'n_counts', 'n_genes', 'file', 'mito', 'doublet_scores', 'predicted_doublets', 'old_annotation_uniform', 'organ', 'Sort_id', 'age', 'method', 'donor', 'sex', 'Sample', 'scvi_clusters', 'is_maternal_contaminant', 'anno_lvl_2_final_clean', 'celltype_annotation', 'filter_rna', 'has_contig', 'filter_contig_quality', 'filter_contig_VDJ', 'filter_contig_VJ', 'contig_QC_pass', 'filter_contig', 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'd_call_VDJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ', 'duplicate_count_VJ', 'duplicate_count_VDJ_1', 'duplicate_count_VJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VDJ_3', 'junction_aa_VDJ', 'junction_aa_VJ', 'locus_status', 'locus_status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary', 'mu_count_VDJ', 'mu_count_VJ', 'mu_freq_VDJ', 'mu_freq_VJ', 'mu_count', 'mu_freq', 'junction_length_VDJ', 'junction_length_VJ', 'junction_aa_length_VDJ', 'junction_aa_length_VJ', 'np1_length_VDJ', 'np1_length_VJ', 'np2_length_VDJ', 'clone_id_size', 'clone_id_size_max_3'
#     var: 'GeneID', 'GeneName', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'scvi_model_var'
#     uns: 'dendrogram_scvi_clusters', 'locus_status_summary_colors', 'scvi'
#     obsm: 'X_scvi', 'X_umap'
#     obsp: 'scvi_connectivities', 'scvi_distances'>

# %%
cdata.obs['celltype_annotation'].value_counts()
# Out:
# celltype_annotation
# NK                    13145
# MATURE_B               8901
# CD4+T                  6782
# LARGE_PRE_B            4702
# SMALL_PRE_B            4642
# CD8+T                  4382
# TYPE_1_INNATE_T        3151
# HIGH_MITO              3108
# TREG                   2944
# B1                     2897
# LATE_PRO_B             2887
# PRO_B                  2771
# DP(Q)_T                1982
# ILC3                   1884
# DP(P)_T                1825
# CYCLING_NK             1633
# TYPE_3_INNATE_T        1507
# ABT(ENTRY)             1286
# IMMATURE_B             1106
# CYCLING_T               971
# PRE_PRO_B               967
# CYCLING_B               920
# HSC_MPP                 757
# CYCLING_MPP             636
# CD8AA                   512
# LMPP_MLP                315
# ILC2                    290
# MEMP                    276
# DOUBLET_ERY_B           138
# DOUBLET                 118
# LOW_Q_INCONSISTENT       97
# CYCLING_MEMP             91
# DN(P)_T                  67
# CYCLING_ILC              64
# CMP                      48
# DN(Q)_T                  38
# DN(early)_T              36
# MEP                      30
# GMP                      30
# PLASMA_B                 25
# PROMONOCYTE               9
# PROMYELOCYTE              4
# EARLY_MK                  2
# Name: count, dtype: int64

# %%
# make a subset??

cdata_Bcell = cdata[cdata.obs['celltype_annotation'].isin
                    (['MATURE_B', 'LARGE_PRE_B', 'SMALL_PRE_B', 'PRO_B', 'LATE_PRO_B',
                     'B1', 'PRE_PRO_B', 'IMMATURE_B', 'CYCLING_B', 'PLASMA_B'])]

# %%
cdata_Bcell.obs['celltype_annotation'].value_counts()
# Out:
# MATURE_B       8901
# LARGE_PRE_B    4702
# SMALL_PRE_B    4642
# B1             2897
# LATE_PRO_B     2887
# PRO_B          2771
# IMMATURE_B     1106
# PRE_PRO_B       967
# CYCLING_B       920
# PLASMA_B         25
# Name: celltype_annotation, dtype: int64

# %%
# save data
cdata_Bcell.write_h5ad("data/Fetal/FICA_Bcell_BCR_Suo2022.h5ad", compression="gzip")
